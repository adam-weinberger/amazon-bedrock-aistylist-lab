# %% [markdown]
# ![Embeddings](./images/AIStylist.png)
# # AI Stylist - Conversational Shopping Experience with Amazon Bedrock
#
#
# In this notebook, we will build an AI virtual assistant acting as your stylist. You will learn how to build an application that helps users choose clothes from a product catalog, all powered by Large Language Models (LLMs). We will leverage Amazon Bedrock for using the Foundation Models (FMs).

# %% [markdown]
# ### Context
# Virtual Assistants are becoming increasingly popular as LLMs start to power the interaction with users. These applications demand an ability to `understand` the intent of the user input and generate adaptable sequence of calls to language models and various utilities depending on user input.
#
# ### Overview
#
# Conversational interfaces such as chatbots and virtual assistants can be used to enhance the customer experience. Virtual assistants use natural language processing (NLP) and machine learning algorithms to understand and respond to user queries. Chatbots can be used in a variety of applications, such as customer service, sales, and e-commerce, to provide quick and efficient responses to users. They can be accessed through various channels such as websites, social media platforms, and messaging apps.
#
# ### Pattern
# We can improve upon this process by implementing an architecture called `Retreival Augmented Generation (RAG)`. RAG retrieves data from outside the language model (non-parametric) and augments the prompts by adding the relevant retrieved data in context. Virtual assistants need ability to determine the sequence of events needed to generate the final results and as such we build towards the use, `plan-and-execute` agents along with `Zero-shot ReAct` which is an action agent and uses [`ReAct`](https://arxiv.org/pdf/2205.00445.pdf) pattern to select the appropriate calls. These will then develop into `Agents` concept. The Agent interface enables such flexibility for these applications.
#
# There are two primary categories of agents:
#
# - Action agents: At each interval, determine the subsequent action utilizing the outputs of all previous actions.
# - Plan-and-execute agents: Determine the complete order of actions initially, then implement them all without updating the plan.
#
# ### Challenges
# - Parse the user query and extracting information which can be used to search the catalog
# - Reform the prompts to bring products from the catalog
# - Search product catalog to bring relevant products with details like product id, description etc
# - Generate relevant images for a style based on the user chat
# - Continue the shopping experience workflow for adding products or finalizing the sale
# - Identify relevant products based on user location or questions asked by user
#
# ### Proposal
# To the above challenges, this notebook proposes the following strategy
#
# #### Prepare documents
# ![Embeddings](./images/embeddings_lang.png)
#
# Before being able to answer the questions, the product catalog must be processed and a stored in a document store index
# - Load the product catalog and specifically the descriptions
# - Process and split them into smaller chunks
# - Create a numerical vector representation of each chunk using Amazon Bedrock Titan Embeddings model
# - Create an index using the chunks and the corresponding embeddings
#
# #### Catalog operations. Fetch relevant products from the catalog
# We need to leverage the LLM for the following
# - Extract information of the `intent` and other details like `place` , objective of the purchase
# - Use [LangChain](https://python.langchain.com/docs/get_started/introduction) as an orchestrator to do a similarity search from the vector store and bring back the artifacts matching the query
# - Extract information for `Product ID` from the search results  and conduct a search to bring further details of the selected products
# - Leverage [LangChain](https://python.langchain.com/docs/get_started/introduction) to orchestrate and call API's using the `ReAct` framework to bring other details like weather and conduct search to bring back the relevant products
#
# #### Query
# - Identify the `intent` of the query
# - Orchestrate the workflow to move the users to the next steps in their purchase journey
#
# ![Question](./images/chatbot_lang.png)
#
# After the document index is prepared, you can ask questions and related documents will be fetched. The following steps will be executed.
# - Create an embedding of the input question
# - Compare the question embedding with the embeddings in the index
# - Fetch the (top N) relevant document chunks
# - Add those chunks as part of the context in the prompt
# - Send the prompt to the model under Amazon Bedrock
# - Get the contextual answer based on the documents retrieved

# %% [markdown]
# ## Virtual Assistant using Amazon Bedrock
#
# ![Amazon Bedrock - Conversational Interface](./images/context-aware-chatbot.png)
#
# ## Langchain framework for building Virtual Assistants with Amazon Bedrock
# In conversational interfaces such as virtual assistants, it is highly important to remember previous interactions, both at a short term but also at a long term level.
#
# LangChain provides memory components in two forms. First, LangChain provides helper utilities for managing and manipulating previous chat messages. These are designed to be modular and useful regardless of how they are used. Secondly, LangChain is able to retrieve previous conversations end other context fromvector stores.
# It allows us to easily define and interact with different types of abstractions, which make it easy to build powerful chatbots.
#
# ## Building Chatbot with Context - Key Elements
#
# The first process in a building a contextual-aware chatbot is to **generate embeddings** for the context. Typically, you will have an ingestion process which will run through your embedding model and generate the embeddings which will be stored in a sort of a vector store. In this example we are using Titan Embeddings model for this
#
# ![Embeddings](./images/embeddings_lang.png)
#
# The second process is the user request orchestration, interaction, invoking and returning the results
#
# ![Chatbot](./images/chatbot_lang.png)
#
# ## Architecture
# ![Architecture](./images/Architecture.png)

# %% [markdown]
# ### <font color='red'>Setup</font>
# ---
# <font color='red'>⚠️ ⚠️ ⚠️</font>
# Before running this notebook, ensure you've run the [Intro to Bedrock notebook](./intro_to_bedrock.ipynb) notebook. <font color='red'>⚠️ ⚠️ ⚠️</font>
#
# ---

# %% [markdown]
# Install the requirements file with the command below. You will get the following error `package versions have conflicting dependencies.` but you can ignore it.

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: aiohttp==3.9.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (3.9.3)
# Requirement already satisfied: aiosignal==1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: alabaster==0.7.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (0.7.16)
# Requirement already satisfied: annotated-types==0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: anyio==3.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: argon2-cffi==23.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: astroid==2.15.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (2.15.8)
# Requirement already satisfied: astropy==6.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (6.0.0)
# Requirement already satisfied: astropy-iers-data==0.2024.1.29.0.30.37 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (0.2024.1.29.0.30.37)
# Requirement already satisfied: asttokens==2.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (2.4.1)
# Requirement already satisfied: async-lru==2.0.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (2.0.4)
# Requirement already satisfied: async-timeout==4.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 14)) (4.0.3)
# Requirement already satisfied: atomicwrites==1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 15)) (1.4.1)
# Requirement already satisfied: attrs==23.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 16)) (23.2.0)
# Requirement already satisfied: autopep8==2.0.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 17)) (2.0.4)
# Requirement already satisfied: autovizwidget==0.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 18)) (0.21.0)
# Requirement already satisfied: awscli==1.32.64 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 19)) (1.32.64)
# Requirement already satisfied: Babel==2.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 20)) (2.14.0)
# Requirement already satisfied: backoff==2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 21)) (2.2.1)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 22)) (4.12.3)
# Requirement already satisfied: binaryornot==0.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 23)) (0.4.4)
# Requirement already satisfied: bitarray==2.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 24)) (2.9.2)
# Requirement already satisfied: black==24.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 25)) (24.1.1)
# Requirement already satisfied: bleach==6.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 26)) (6.1.0)
# Requirement already satisfied: blinker==1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 27)) (1.7.0)
# Requirement already satisfied: bokeh==3.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 28)) (3.3.4)
# Requirement already satisfied: boto3==1.34.64 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 29)) (1.34.64)
# Requirement already satisfied: botocore==1.34.64 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 30)) (1.34.64)
# Requirement already satisfied: Bottleneck==1.3.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 31)) (1.3.7)
# Requirement already satisfied: Brotli==1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 32)) (1.1.0)
# Requirement already satisfied: brotlipy==0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 33)) (0.7.0)
# Requirement already satisfied: cached-property==1.5.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 34)) (1.5.2)
# Requirement already satisfied: certifi==2024.2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 35)) (2024.2.2)
# Requirement already satisfied: cffi==1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 36)) (1.16.0)
# Requirement already satisfied: chardet==5.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 37)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 38)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 39)) (8.1.7)
# Requirement already satisfied: cloudpickle==2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 40)) (2.2.1)
# Requirement already satisfied: colorama==0.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 41)) (0.4.4)
# Requirement already satisfied: comm==0.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 42)) (0.2.1)
# Requirement already satisfied: contextlib2==21.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 43)) (21.6.0)
# Requirement already satisfied: contourpy==1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 44)) (1.2.0)
# Requirement already satisfied: cookiecutter==2.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 45)) (2.5.0)
# Requirement already satisfied: coverage==7.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 46)) (7.4.1)
# Requirement already satisfied: cryptography==42.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 47)) (42.0.2)
# Requirement already satisfied: cycler==0.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 48)) (0.12.1)
# Requirement already satisfied: Cython==3.0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 49)) (3.0.8)
# Requirement already satisfied: cytoolz==0.12.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 50)) (0.12.2)
# Requirement already satisfied: dask==2024.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 51)) (2024.1.1)
# Requirement already satisfied: dataclasses-json==0.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 52)) (0.6.4)
# Requirement already satisfied: dataclasses-json-speakeasy==0.5.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 53)) (0.5.11)
# Requirement already satisfied: debugpy==1.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 54)) (1.8.0)
# Requirement already satisfied: decorator==5.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 55)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 56)) (0.7.1)
# Requirement already satisfied: diff-match-patch==20230430 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 57)) (20230430)
# Requirement already satisfied: dill==0.3.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 58)) (0.3.8)
# Requirement already satisfied: distributed==2024.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 59)) (2024.1.1)
# Requirement already satisfied: docker==6.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 60)) (6.1.3)
# Requirement already satisfied: docstring-to-markdown==0.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 61)) (0.13)
# Requirement already satisfied: docutils==0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 62)) (0.16)
# Requirement already satisfied: dparse==0.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 63)) (0.6.3)
# Requirement already satisfied: emoji==2.10.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 64)) (2.10.1)
# Requirement already satisfied: entrypoints==0.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 65)) (0.4)
# Requirement already satisfied: et-xmlfile==1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 66)) (1.1.0)
# Requirement already satisfied: exceptiongroup==1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 67)) (1.2.0)
# Requirement already satisfied: executing==2.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 68)) (2.0.1)
# Requirement already satisfied: faiss-cpu==1.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 69)) (1.7.4)
# Requirement already satisfied: faiss-gpu==1.7.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 70)) (1.7.2)
# Requirement already satisfied: fastcache==1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 71)) (1.1.0)
# Requirement already satisfied: fastjsonschema==2.19.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 72)) (2.19.1)
# Requirement already satisfied: filelock==3.13.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 73)) (3.13.1)
# Requirement already satisfied: filetype==1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 74)) (1.2.0)
# Requirement already satisfied: flake8==6.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 75)) (6.0.0)
# Requirement already satisfied: Flask==3.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 76)) (3.0.1)
# Requirement already satisfied: Flask-Cors==4.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 77)) (4.0.0)
# Requirement already satisfied: fonttools==4.47.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 78)) (4.47.2)
# Requirement already satisfied: fqdn==1.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 79)) (1.5.1)
# Requirement already satisfied: frozenlist==1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 80)) (1.4.1)
# Requirement already satisfied: fsspec==2023.12.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 81)) (2023.12.2)
# Requirement already satisfied: future==0.18.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 82)) (0.18.3)
# Requirement already satisfied: gevent==23.9.0.post1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 83)) (23.9.0.post1)
# Requirement already satisfied: gmpy2==2.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 84)) (2.1.2)
# Requirement already satisfied: google-pasta==0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 85)) (0.2.0)
# Requirement already satisfied: greenlet==3.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 86)) (3.0.3)
# Requirement already satisfied: h5py==3.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 87)) (3.10.0)
# Requirement already satisfied: hdijupyterutils==0.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 88)) (0.21.0)
# Requirement already satisfied: idna==3.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 89)) (3.6)
# Requirement already satisfied: imagecodecs==2024.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 90)) (2024.1.1)
# Requirement already satisfied: imageio==2.33.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 91)) (2.33.1)
# Requirement already satisfied: imagesize==1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 92)) (1.4.1)
# Requirement already satisfied: immutables==0.20 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 93)) (0.20)
# Requirement already satisfied: importlib-metadata==6.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 94)) (6.11.0)
# Requirement already satisfied: importlib-resources==6.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 95)) (6.1.1)
# Requirement already satisfied: inflection==0.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 96)) (0.5.1)
# Requirement already satisfied: iniconfig==2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 97)) (2.0.0)
# Requirement already satisfied: intel-openmp==2024.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 98)) (2024.0.2)
# Requirement already satisfied: intervaltree==3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 99)) (3.1.0)
# Requirement already satisfied: ipykernel==6.29.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 100)) (6.29.0)
# Requirement already satisfied: ipython==8.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 101)) (8.21.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 102)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 103)) (8.1.1)
# Requirement already satisfied: isoduration==20.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 104)) (20.11.0)
# Requirement already satisfied: isort==5.13.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 105)) (5.13.2)
# Requirement already satisfied: itsdangerous==2.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 106)) (2.1.2)
# Requirement already satisfied: jaraco.classes==3.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 107)) (3.3.0)
# Requirement already satisfied: jedi==0.18.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 108)) (0.18.2)
# Requirement already satisfied: jeepney==0.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 109)) (0.8.0)
# Requirement already satisfied: jellyfish==1.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 110)) (1.0.3)
# Requirement already satisfied: Jinja2==3.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 111)) (3.1.3)
# Requirement already satisfied: jmespath==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 112)) (1.0.1)
# Requirement already satisfied: joblib==1.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 113)) (1.3.2)
# Requirement already satisfied: json5==0.9.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 114)) (0.9.14)
# Requirement already satisfied: jsonpatch==1.33 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 115)) (1.33)
# Requirement already satisfied: jsonpath-python==1.0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 116)) (1.0.6)
# Requirement already satisfied: jsonpointer==2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 117)) (2.4)
# Requirement already satisfied: jsonschema==4.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 118)) (4.21.1)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 119)) (2023.12.1)
# Requirement already satisfied: jupyter==1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 120)) (1.0.0)
# Requirement already satisfied: jupyter_client==8.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 121)) (8.6.0)
# Requirement already satisfied: jupyter-console==6.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 122)) (6.6.3)
# Requirement already satisfied: jupyter_core==5.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 123)) (5.7.1)
# Requirement already satisfied: jupyter-events==0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 124)) (0.9.0)
# Requirement already satisfied: jupyter-lsp==2.2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 125)) (2.2.2)
# Requirement already satisfied: jupyter_server==2.12.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 126)) (2.12.5)
# Requirement already satisfied: jupyter_server_terminals==0.5.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 127)) (0.5.2)
# Requirement already satisfied: jupyterlab==4.0.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 128)) (4.0.12)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 129)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.25.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 130)) (2.25.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 131)) (3.0.9)
# Requirement already satisfied: keyring==24.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 132)) (24.3.0)
# Requirement already satisfied: kiwisolver==1.4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 133)) (1.4.5)
# Requirement already satisfied: langchain==0.0.309 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 134)) (0.0.309)
# Requirement already satisfied: langchain-community==0.0.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 135)) (0.0.28)
# Requirement already satisfied: langchain-core==0.1.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 136)) (0.1.32)
# Requirement already satisfied: langchain-text-splitters==0.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 137)) (0.0.1)
# Requirement already satisfied: langdetect==1.0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 138)) (1.0.9)
# Requirement already satisfied: langsmith==0.0.92 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 139)) (0.0.92)
# Requirement already satisfied: lazy_loader==0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 140)) (0.3)
# Requirement already satisfied: lazy-object-proxy==1.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 141)) (1.10.0)
# Requirement already satisfied: llvmlite==0.41.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 142)) (0.41.1)
# Requirement already satisfied: locket==1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 143)) (1.0.0)
# Requirement already satisfied: lxml==5.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 144)) (5.1.0)
# Requirement already satisfied: lz4==4.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 145)) (4.3.3)
# Requirement already satisfied: markdown-it-py==3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 146)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 147)) (2.1.4)
# Requirement already satisfied: marshmallow==3.20.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 148)) (3.20.2)
# Requirement already satisfied: matplotlib==3.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 149)) (3.8.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 150)) (0.1.6)
# Requirement already satisfied: mccabe==0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 151)) (0.7.0)
# Requirement already satisfied: mdurl==0.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 152)) (0.1.2)
# Requirement already satisfied: mistune==3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 153)) (3.0.2)
# Requirement already satisfied: mkl==2024.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 154)) (2024.0.0)
# Requirement already satisfied: mkl_fft==1.3.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 155)) (1.3.8)
# Requirement already satisfied: mkl-service==2.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 156)) (2.4.0)
# Requirement already satisfied: mock==5.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 157)) (5.1.0)
# Requirement already satisfied: more-itertools==10.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 158)) (10.2.0)
# Requirement already satisfied: mpmath==1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 159)) (1.3.0)
# Requirement already satisfied: msgpack==1.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 160)) (1.0.7)
# Requirement already satisfied: multidict==6.0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 161)) (6.0.5)
# Requirement already satisfied: multiprocess==0.70.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 162)) (0.70.16)
# Requirement already satisfied: munkres==1.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 163)) (1.1.4)
# Requirement already satisfied: mypy-extensions==1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 164)) (1.0.0)
# Requirement already satisfied: nbclient==0.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 165)) (0.8.0)
# Requirement already satisfied: nbconvert==7.14.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 166)) (7.14.2)
# Requirement already satisfied: nbformat==5.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 167)) (5.9.2)
# Requirement already satisfied: nest_asyncio==1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 168)) (1.6.0)
# Requirement already satisfied: networkx==3.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 169)) (3.2.1)
# Requirement already satisfied: nltk==3.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 170)) (3.8.1)
# Requirement already satisfied: nose==1.3.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 171)) (1.3.7)
# Requirement already satisfied: notebook==7.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 172)) (7.0.7)
# Requirement already satisfied: notebook_shim==0.2.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 173)) (0.2.3)
# Requirement already satisfied: numba==0.58.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 174)) (0.58.1)
# Requirement already satisfied: numexpr==2.8.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 175)) (2.8.8)
# Requirement already satisfied: numpy==1.26.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 176)) (1.26.4)
# Requirement already satisfied: numpydoc==1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 177)) (1.6.0)
# Requirement already satisfied: openpyxl==3.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 178)) (3.1.2)
# Requirement already satisfied: orjson==3.9.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 179)) (3.9.15)
# Requirement already satisfied: overrides==7.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 180)) (7.7.0)
# Requirement already satisfied: packaging==23.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 181)) (23.2)
# Requirement already satisfied: pandas==2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 182)) (2.2.0)
# Requirement already satisfied: pandocfilters==1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 183)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 184)) (0.8.3)
# Requirement already satisfied: partd==1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 185)) (1.4.1)
# Requirement already satisfied: path==16.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 186)) (16.9.0)
# Requirement already satisfied: pathlib2==2.3.7.post1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 187)) (2.3.7.post1)
# Requirement already satisfied: pathos==0.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 188)) (0.3.2)
# Requirement already satisfied: pathspec==0.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 189)) (0.12.1)
# Requirement already satisfied: patsy==0.5.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 190)) (0.5.6)
# Requirement already satisfied: pexpect==4.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 191)) (4.9.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 192)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 193)) (9.5.0)
# Requirement already satisfied: pip==23.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 194)) (23.3.2)
# Requirement already satisfied: pkginfo==1.9.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 195)) (1.9.6)
# Requirement already satisfied: pkgutil_resolve_name==1.3.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 196)) (1.3.10)
# Requirement already satisfied: platformdirs==4.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 197)) (4.2.0)
# Requirement already satisfied: plotly==5.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 198)) (5.18.0)
# Requirement already satisfied: pluggy==1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 199)) (1.4.0)
# Requirement already satisfied: ply==3.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 200)) (3.11)
# Requirement already satisfied: pox==0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 201)) (0.3.4)
# Requirement already satisfied: ppft==1.7.6.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 202)) (1.7.6.8)
# Requirement already satisfied: prometheus-client==0.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 203)) (0.19.0)
# Requirement already satisfied: prompt-toolkit==3.0.42 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 204)) (3.0.42)
# Requirement already satisfied: protobuf==4.25.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 205)) (4.25.3)
# Requirement already satisfied: psutil==5.9.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 206)) (5.9.8)
# Requirement already satisfied: psycopg2==2.9.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 207)) (2.9.9)
# Requirement already satisfied: psycopg2-binary==2.9.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 208)) (2.9.9)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 209)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 210)) (0.2.2)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 211)) (9.0.0)
# Requirement already satisfied: py4j==0.10.9.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 212)) (0.10.9.5)
# Requirement already satisfied: pyarrow==15.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 213)) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix==0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 214)) (0.6)
# Requirement already satisfied: pyasn1==0.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 215)) (0.5.1)
# Requirement already satisfied: pycodestyle==2.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 216)) (2.10.0)
# Requirement already satisfied: pycosat==0.6.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 217)) (0.6.6)
# Requirement already satisfied: pycparser==2.21 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 218)) (2.21)
# Requirement already satisfied: pycryptodome==3.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 219)) (3.20.0)
# Requirement already satisfied: pycurl==7.45.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 220)) (7.45.1)
# Requirement already satisfied: pydantic==2.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 221)) (2.6.4)
# Requirement already satisfied: pydantic_core==2.16.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 222)) (2.16.3)
# Requirement already satisfied: pydocstyle==6.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 223)) (6.3.0)
# Requirement already satisfied: pyerfa==2.0.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 224)) (2.0.1.1)
# Requirement already satisfied: pyflakes==3.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 225)) (3.0.1)
# Requirement already satisfied: Pygments==2.17.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 226)) (2.17.2)
# Requirement already satisfied: pykerberos==1.2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 227)) (1.2.4)
# Requirement already satisfied: pylint==2.17.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 228)) (2.17.7)
# Requirement already satisfied: pylint-venv==3.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 229)) (3.0.3)
# Requirement already satisfied: pyls-spyder==0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 230)) (0.4.0)
# Requirement already satisfied: pynvml==11.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 231)) (11.5.0)
# Requirement already satisfied: pyodbc==5.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 232)) (5.0.1)
# Requirement already satisfied: pyOpenSSL==24.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 233)) (24.0.0)
# Requirement already satisfied: pyparsing==3.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 234)) (3.1.1)
# Requirement already satisfied: pypdf==3.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 235)) (3.8.1)
# Requirement already satisfied: PyQt5==5.15.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 236)) (5.15.9)
# Requirement already satisfied: PyQt5-sip==12.12.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 237)) (12.12.2)
# Requirement already satisfied: PyQtWebEngine==5.15.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 238)) (5.15.4)
# Requirement already satisfied: pyrsistent==0.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 239)) (0.20.0)
# Requirement already satisfied: PySocks==1.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 240)) (1.7.1)
# Requirement already satisfied: pyspark==3.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 241)) (3.3.0)
# Requirement already satisfied: pyspnego==0.9.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 242)) (0.9.1)
# Requirement already satisfied: pytest==8.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 243)) (8.0.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 244)) (2.8.2)
# Requirement already satisfied: python-iso639==2024.2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 245)) (2024.2.7)
# Requirement already satisfied: python-json-logger==2.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 246)) (2.0.7)
# Requirement already satisfied: python-lsp-black==2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 247)) (2.0.0)
# Requirement already satisfied: python-lsp-jsonrpc==1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 248)) (1.1.2)
# Requirement already satisfied: python-lsp-server==1.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 249)) (1.7.4)
# Requirement already satisfied: python-magic==0.4.27 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 250)) (0.4.27)
# Requirement already satisfied: python-slugify==8.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 251)) (8.0.3)
# Requirement already satisfied: python-weather==1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 252)) (1.1.2)
# Requirement already satisfied: pytoolconfig==1.2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 253)) (1.2.5)
# Requirement already satisfied: pytz==2024.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 254)) (2024.1)
# Requirement already satisfied: PyWavelets==1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 255)) (1.4.1)
# Requirement already satisfied: pyxdg==0.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 256)) (0.28)
# Requirement already satisfied: PyYAML==6.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 257)) (6.0.1)
# Requirement already satisfied: pyzmq==25.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 258)) (25.1.2)
# Requirement already satisfied: QDarkStyle==3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 259)) (3.1)
# Requirement already satisfied: qstylizer==0.2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 260)) (0.2.2)
# Requirement already satisfied: QtAwesome==1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 261)) (1.3.0)
# Requirement already satisfied: qtconsole==5.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 262)) (5.4.4)
# Requirement already satisfied: QtPy==2.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 263)) (2.4.1)
# Requirement already satisfied: rapidfuzz==3.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 264)) (3.6.1)
# Requirement already satisfied: referencing==0.33.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 265)) (0.33.0)
# Requirement already satisfied: regex==2023.12.25 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 266)) (2023.12.25)
# Requirement already satisfied: requests==2.31.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 267)) (2.31.0)
# Requirement already satisfied: requests-kerberos==0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 268)) (0.14.0)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 269)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 270)) (0.1.1)
# Requirement already satisfied: rich==13.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 271)) (13.7.0)
# Requirement already satisfied: rope==1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 272)) (1.12.0)
# Requirement already satisfied: rpds-py==0.17.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 273)) (0.17.1)
# Requirement already satisfied: rsa==4.7.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 274)) (4.7.2)
# Requirement already satisfied: Rtree==1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 275)) (1.2.0)
# Requirement already satisfied: ruamel.yaml==0.18.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 276)) (0.18.5)
# Requirement already satisfied: ruamel.yaml.clib==0.2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 277)) (0.2.7)
# Requirement already satisfied: ruamel-yaml-conda==0.15.80 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 278)) (0.15.80)
# Requirement already satisfied: s3fs==0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 279)) (0.4.2)
# Requirement already satisfied: s3transfer==0.10.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 280)) (0.10.1)
# Requirement already satisfied: sagemaker==2.210.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 281)) (2.210.0)
# Requirement already satisfied: sagemaker_pyspark==1.4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 282)) (1.4.5)
# Requirement already satisfied: schema==0.7.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 283)) (0.7.5)
# Requirement already satisfied: scikit-image==0.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 284)) (0.22.0)
# Requirement already satisfied: scikit-learn==1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 285)) (1.4.0)
# Requirement already satisfied: scipy==1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 286)) (1.12.0)
# Requirement already satisfied: seaborn==0.13.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 287)) (0.13.2)
# Requirement already satisfied: SecretStorage==3.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 288)) (3.3.3)
# Requirement already satisfied: Send2Trash==1.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 289)) (1.8.2)
# Requirement already satisfied: setuptools==69.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 290)) (69.0.3)
# Requirement already satisfied: shap==0.44.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 291)) (0.44.0)
# Requirement already satisfied: sip==6.7.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 292)) (6.7.12)
# Requirement already satisfied: six==1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 293)) (1.16.0)
# Requirement already satisfied: slicer==0.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 294)) (0.0.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 295)) (1.0.1)
# Requirement already satisfied: sniffio==1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 296)) (1.3.1)
# Requirement already satisfied: snowballstemmer==2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 297)) (2.2.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 298)) (2.4.0)
# Requirement already satisfied: soupsieve==2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 299)) (2.5)
# Requirement already satisfied: sparkmagic==0.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 300)) (0.21.0)
# Requirement already satisfied: Sphinx==7.2.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 301)) (7.2.6)
# Requirement already satisfied: sphinxcontrib-applehelp==1.0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 302)) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp==1.0.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 303)) (1.0.6)
# Requirement already satisfied: sphinxcontrib-htmlhelp==2.0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 304)) (2.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 305)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp==1.0.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 306)) (1.0.7)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 307)) (1.1.10)
# Requirement already satisfied: sphinxcontrib-websupport==1.2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 308)) (1.2.7)
# Requirement already satisfied: spyder==5.4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 309)) (5.4.5)
# Requirement already satisfied: spyder-kernels==2.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 310)) (2.4.4)
# Requirement already satisfied: SQLAlchemy==2.0.28 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 311)) (2.0.28)
# Requirement already satisfied: stack-data==0.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 312)) (0.6.2)
# Requirement already satisfied: statsmodels==0.14.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 313)) (0.14.1)
# Requirement already satisfied: sympy==1.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 314)) (1.12)
# Requirement already satisfied: tables==3.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 315)) (3.9.2)
# Requirement already satisfied: tabulate==0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 316)) (0.9.0)
# Requirement already satisfied: tbb==2021.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 317)) (2021.11.0)
# Requirement already satisfied: tblib==2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 318)) (2.0.0)
# Requirement already satisfied: tenacity==8.2.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 319)) (8.2.3)
# Requirement already satisfied: terminado==0.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 320)) (0.18.0)
# Requirement already satisfied: testpath==0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 321)) (0.6.0)
# Requirement already satisfied: text-unidecode==1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 322)) (1.3)
# Requirement already satisfied: textdistance==4.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 323)) (4.5.0)
# Requirement already satisfied: threadpoolctl==3.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 324)) (3.2.0)
# Requirement already satisfied: three-merge==0.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 325)) (0.1.1)
# Requirement already satisfied: tifffile==2024.1.30 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 326)) (2024.1.30)
# Requirement already satisfied: tinycss2==1.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 327)) (1.2.1)
# Requirement already satisfied: toml==0.10.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 328)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 329)) (2.0.1)
# Requirement already satisfied: tomlkit==0.12.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 330)) (0.12.3)
# Requirement already satisfied: toolz==0.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 331)) (0.12.1)
# Requirement already satisfied: tornado==6.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 332)) (6.3.3)
# Requirement already satisfied: tqdm==4.66.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 333)) (4.66.2)
# Requirement already satisfied: traitlets==5.14.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 334)) (5.14.1)
# Requirement already satisfied: typed-ast==1.5.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 335)) (1.5.5)
# Requirement already satisfied: types-python-dateutil==2.8.19.20240106 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 336)) (2.8.19.20240106)
# Requirement already satisfied: typing_extensions==4.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 337)) (4.9.0)
# Requirement already satisfied: typing-inspect==0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 338)) (0.9.0)
# Requirement already satisfied: typing-utils==0.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 339)) (0.1.0)
# Requirement already satisfied: tzdata==2024.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 340)) (2024.1)
# Requirement already satisfied: ujson==5.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 341)) (5.9.0)
# Requirement already satisfied: unicodedata2==15.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 342)) (15.1.0)
# Requirement already satisfied: unstructured==0.12.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 343)) (0.12.6)
# Requirement already satisfied: unstructured-client==0.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 344)) (0.18.0)
# Requirement already satisfied: uri-template==1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 345)) (1.3.0)
# Requirement already satisfied: urllib3==1.26.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 346)) (1.26.18)
# Requirement already satisfied: watchdog==3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 347)) (3.0.0)
# Requirement already satisfied: wcwidth==0.2.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 348)) (0.2.13)
# Requirement already satisfied: webcolors==1.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 349)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 350)) (0.5.1)
# Requirement already satisfied: websocket-client==1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 351)) (1.7.0)
# Requirement already satisfied: Werkzeug==3.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 352)) (3.0.1)
# Requirement already satisfied: whatthepatch==1.0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 353)) (1.0.5)
# Requirement already satisfied: wheel==0.42.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 354)) (0.42.0)
# Requirement already satisfied: widgetsnbextension==4.0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 355)) (4.0.9)
# Requirement already satisfied: wrapt==1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 356)) (1.16.0)
# Requirement already satisfied: wurlitzer==3.0.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 357)) (3.0.3)
# Requirement already satisfied: XlsxWriter==3.1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 358)) (3.1.9)
# Requirement already satisfied: xyzservices==2023.10.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 359)) (2023.10.1)
# Requirement already satisfied: yapf==0.40.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 360)) (0.40.1)
# Requirement already satisfied: yarl==1.9.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 361)) (1.9.4)
# Requirement already satisfied: zict==3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 362)) (3.0.0)
# Requirement already satisfied: zipp==3.17.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 363)) (3.17.0)
# Requirement already satisfied: zope.event==5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 364)) (5.0)
# Requirement already satisfied: zope.interface==6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from -r ../requirements.txt (line 365)) (6.1)
# INFO: pip is looking at multiple versions of autovizwidget to determine which version is compatible with other requirements. This could take a while.
# ERROR: Cannot install autovizwidget==0.21.0 and pandas==2.2.0 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     The user requested pandas==2.2.0
#     autovizwidget 0.21.0 depends on pandas<2.0.0 and >=0.20.1
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %% [markdown]
# ## Configure Bedrock
#
# Create the necessary clients to invoke Bedrock models. If you would need to pass in a certain role then set those values appropriately.
# We begin with instantiating the LLM and the Embeddings model. Here we are using Anthropic Claude V2 for text generation and Titan Embeddings G1 - Text for text embeddings.
#
# Note: It is possible to choose other models available with Bedrock. You can replace the `model_id` as follows to change the model.
#
# `llm = Bedrock(model_id="anthropic.claude-v2")`
#
# You can read about all the available model IDs [here](https://docs.aws.amazon.com/bedrock/latest/userguide/model-ids-arns.html)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import json
import os
from pprint import pprint
import sys
import boto3
import botocore

from langchain.llms.bedrock import Bedrock
from IPython.display import Image

module_path = ".."
sys.path.append(os.path.abspath(module_path))
from utils import bedrock, print_ww


# ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----

os.environ["AWS_DEFAULT_REGION"] = "us-east-1"
# os.environ["AWS_PROFILE"] = ""
# os.environ["BEDROCK_ASSUME_ROLE"] = ""  # E.g. "arn:aws:..."

# Adam: What is the difference between runtime?
boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
    runtime=False)

bedrock_runtime = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None))

model_parameter = {
    "temperature": 0.0, 
    "top_p": .5, 
    "top_k": 250, 
    "max_tokens_to_sample": 2000, 
    "stop_sequences": ["\n\n Human: bye"]
}
llm = Bedrock(
    model_id="anthropic.claude-v2", 
    model_kwargs=model_parameter, 
    client=bedrock_runtime
)
# Out:
# Create new client
#   Using region: us-east-1
# boto3 Bedrock client successfully created!
# bedrock(https://bedrock.us-east-1.amazonaws.com)
# Create new client
#   Using region: us-east-1
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)

# %% [markdown]
# ## Implementation
# This notebook uses the LangChain framework which has integrations with different services and tools that allow efficient building of patterns such as RAG. We will be using the following tools:
#
# - **LLM (Large Language Model)**: Anthropic Claude V2 available through Amazon Bedrock
#
#   This model will be used to understand the document chunks and provide an answer in human friendly manner.
# - **Embeddings Model**: Amazon Titan Embeddings available through Amazon Bedrock
#
#   This model will be used to generate a numerical representation of the textual documents
# - **Document Loader**: [S3FileLoader](https://api.python.langchain.com/en/latest/document_loaders/langchain.document_loaders.s3_file.S3FileLoader.html) and PDF Loader available through LangChain
#
#   This is the loader that can load the documents from a source, for the sake of this notebook we are loading the sample files from a local path. This could easily be replaced with a loader to load documents from enterprise internal systems.
#
# - **Vector Store**: In-Memory store FAISS
#
#   The index helps to compare the input embedding and the document embeddings to find relevant document
# - **Wrapper**: wraps index, vector store, embeddings model and the LLM to abstract away the logic from the user.

# %% [markdown]
# ## Simulate a user ask of the AI Stylist
#
# ![Generate Look](./images/user_prompt.png)
#
# ### Try these prompts if you would like
# - `"I am a female journalist in my 30s traveling to New York next week. What kind of outfit should I wear on my first day at New York Times?"`
# - `"I am male athlete looking for suitable outfit for attending half marathon in San Fransisco."`

# %%
# If you'd like to try your own prompt, edit this parameter!
customer_input = "I am a male consultant in my 30s traveling to New York next week. What kind of outfit should I wear on my first day in the office? "

# Customer id to infuse order history and delivery address
customer_id = "2"

# %% [markdown]
# ## Extract `product relevant` information
#
# We have our product catalog stored in a data base and the key attributes for those are
# 1. Product type
# 2. Age group for the product
# 3. Season for use of the product
# 4. Description of the product
# 5. Images for the product
#
# We will instruct LLM to fetch the relevant information from the user prompt based on the above so we can query our catalog and bring back relevant results. Note we have a very specific prompt template for the `entity extraction`

# %%
# Identify product attributes from customer prompt to generate better results
ner_prompt = """Human: Find person age group, gender, season and the location in the customer input.
Instructions:
The age group can be one of the following: 10-20, 20-30, 30-50, 50+
The gender can be one of the following: Mens, Womens, Other
The gender can also be derived from the name if not explicitly mentioned
The season can be one of the following: summer, winter, spring, fall
The output must be in JSON format inside the tags <attributes></attributes>

If the information of an entity is not available in the input then don't include that entity in the JSON output

Begin!

Customer input: {customer_input}
Assistant:"""
entity_extraction_result = llm(ner_prompt.format(customer_input=customer_input)).strip()
print(entity_extraction_result)
# Out:
# <attributes>
# {"age_group":"30-50", "gender":"Mens", "season":"", "location":"New York"}
# </attributes>

# %% [markdown]
# #### Extract values into JSON
#
# Since we have instructed LLM to return our data as XML wrapping a JSON, we run the necessary extraction steps to fetch the relevant details.

# %%
import re
import json
result = re.search('<attributes>(.*)</attributes>', entity_extraction_result, re.DOTALL)
attributes = json.loads(result.group(1))
attributes
# Out:
# {'age_group': '30-50', 'gender': 'Mens', 'season': '', 'location': 'New York'}

# %% [markdown]
# ## Use Retrieval Augmented Generation (RAG)
#
# We will leverage the semantic search to embed product-accessory catalogs and order history from the embeddings created by `Amazon Titan Embeddings Text v1`
#
# After downloading we can load the documents with the help of [S3FileLoader available under LangChain](https://python.langchain.com/docs/modules/data_connection/document_loaders/) and splitting them into smaller chunks.
#
# Note: The retrieved document/text should be large enough to contain enough information to answer a question; but small enough to fit into the LLM prompt. Also the embeddings model has a limit of the length of input tokens limited to 8k tokens, which roughly translates to ~32000 characters. For the sake of this use-case we are creating chunks of roughly 1000 characters with an overlap of 100 characters using [RecursiveCharacterTextSplitter](https://python.langchain.com/en/latest/modules/indexes/text_splitters/examples/recursive_text_splitter.html).
#
# Here we are fetching our product catalog and creating the embeddings for
# 1. Customer reviews
# 2. Order History
# 3. Product catalog description

# %%
# We will be using the Titan Embeddings Model to generate our Embeddings.
# from langchain.embeddings import BedrockEmbeddings
from langchain_community.embeddings import BedrockEmbeddings
from langchain.vectorstores import FAISS
from langchain.indexes.vectorstore import VectorStoreIndexWrapper
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import S3FileLoader
import numpy as np

# %%
# - create the Titan Embeddings Model
bedrock_embeddings = BedrockEmbeddings(model_id="amazon.titan-embed-text-v1",
                                       client=bedrock_runtime)
customer_reviews_loader = S3FileLoader("sagemaker-example-files-prod-us-east-1", "datasets/image/howser-bedrock/data/aistylist/data/customer_reviews.csv", region_name="us-east-1",)
order_history_loader = S3FileLoader("sagemaker-example-files-prod-us-east-1", "datasets/image/howser-bedrock/data/aistylist/data/order_history.csv", region_name="us-east-1")
products_catalog_loader = S3FileLoader("sagemaker-example-files-prod-us-east-1", "datasets/image/howser-bedrock/data/aistylist/data/products_catalog.csv", region_name="us-east-1")
documents = []
customer_reviews = customer_reviews_loader.load()
order_history = order_history_loader.load()
products_catalog = products_catalog_loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, to test an alternate behavior.
    chunk_size = 1000,
    chunk_overlap  = 100,
)

# %%
# Embedding data here. Add more data for better results
documents += text_splitter.split_documents(customer_reviews)
documents += text_splitter.split_documents(order_history)
documents += text_splitter.split_documents(products_catalog)
vectorstore_faiss = FAISS.from_documents(
    documents,
    bedrock_embeddings,
)

# %%
wrapper_store_faiss = VectorStoreIndexWrapper(vectorstore=vectorstore_faiss)
query_embedding = vectorstore_faiss.embedding_function(customer_input)
np.array(query_embedding)
# Out:
# array([-0.02075195, -0.14453125, -0.01196289, ...,  0.2890625 ,
#         0.14941406,  0.35742188])

# %% [markdown]
# ## Generate *`n`* style recommendations
#
# In this section, we will see how to make a [retrieval chain](https://python.langchain.com/docs/use_cases/question_answering/vector_db_qa) which is more comprehensive and robust than the original retrieval system we built above.
#
# The workflow above uses the following process:
# 1. User input is received.
# 2. User input is queried against the vector database to retrieve the relevant products
# 3. Product description and chat memory are inserted into a new prompt to respond to the user input.
# 4. This output is fed into the stable diffusion model to return the relevant images
#
# However, more complex methods of interacting with the user input can generate more accurate results in RAG architectures. One of the popular mechanisms which can increase accuracy of these retrieval systems is utilizing more than one call to an LLM in order to reformat the user input for more effective search to your vector database. A better workflow is:
#
# 1. User input is received.
# 2. An LLM is used to reword the user input to be a better search query for the vector database based on the chat history and product description. This could include things like condensing, rewording, addition of chat context, or stylistic changes.
# 3. Reformatted user input is queried against the vector database to retrieve relevant products. The reformatted user input and relevant documents are inserted into a new prompt in order to generate the new style.
# 4. This is then fed into the stable diffusion model to generate the images.
#
# In your application the images can come from pre canned images.
#
# We will now build out this second workflow using LangChain. First we need to make a prompt which will reformat the user input to be more compatible for searching of the vector database. The way we do this is by providing the chat history as well as the some basic instructions to Claude and asking it to condense the input into a single output.

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

prompt_template = """Human: Use the following pieces of context to generate 5 style recommendations for the customer input at the end.
<context>
{context}
</context>
<example>A navy suit with a light blue dress shirt, conservative tie, black oxford shoes, and a leather belt.</example>
<example>A lehenga choli set with a crop top, flowing skirt, and dupatta scarf in lively colors and metallic accents.</example>

Customer Input: {question}
Each style recommendation must be inside the tags <style></style>.
Do not output product physical IDs.
Skip the preamble.
Assistant: """
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# Use RetrievalQA customizations for improving Q&A experience
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore_faiss.as_retriever(
        search_type="similarity", search_kwargs={"k": 6}
    ),
    return_source_documents=False,
    chain_type_kwargs={"prompt": PROMPT},
)
styles_response = qa({"query": customer_input})['result']

# Alternitively we can query using wrapper also
# styles_response = wrapper_store_faiss.query(question= customer_input, llm=llm)

print_ww(styles_response)
# Out:
#  <style>A navy suit with a white dress shirt, blue and red striped tie, black oxford shoes, and a
# brown leather belt.</style>
#
# <style>A gray wool suit with a light blue dress shirt, navy tie, black leather belt, and black cap-
# toe oxford shoes.</style>
#
# <style>A charcoal suit with a white dress shirt, burgundy tie, black leather belt, and black leather
# oxfords.</style>
#
# <style>A dark gray suit with a light pink dress shirt, navy and silver diagonal striped tie, black
# leather belt, and black cap-toe oxford shoes.</style>
#
# <style>A medium gray suit with a light blue dress shirt, red tie with small dots, black leather
# belt, and black leather lace-up oxford shoes.</style>

# %% [markdown]
# ### Prepare the received response
#
# Since we have instructed LLM to return our data is returned as XML wrapping a JSON, we run the necessary extraction steps to fetch the relevant details to generate images for each look.

# %%
# Prepare input to fetch images for each look
styles = re.findall('<style>(.*?)</style>', styles_response)
styles
# Out:
# ['A navy suit with a white dress shirt, blue and red striped tie, black oxford shoes, and a brown leather belt.',
#  'A gray wool suit with a light blue dress shirt, navy tie, black leather belt, and black cap-toe oxford shoes.',
#  'A charcoal suit with a white dress shirt, burgundy tie, black leather belt, and black leather oxfords.',
#  'A dark gray suit with a light pink dress shirt, navy and silver diagonal striped tie, black leather belt, and black cap-toe oxford shoes.',
#  'A medium gray suit with a light blue dress shirt, red tie with small dots, black leather belt, and black leather lace-up oxford shoes.']

# %% [markdown]
# ## Generate Images for the relevant style
#
# Generate an image for each look using the `Stable Diffusion` model
#
# ![Generate Look](./images/generate_look.png)

# %%
from PIL import Image
from IPython import display
from base64 import b64decode
import base64
import io
import json
import os
import sys
import ipywidgets as widgets

# Fetching images for each of style
gender_map = {
    'Womens': 'of a female ',
    'Mens': 'of a male '
}

os.makedirs("data/aistylist", exist_ok=True)
image_strip = ""
for i, style in enumerate(styles):
    request = json.dumps({
        "text_prompts": [
            {"text": f"Full body view {gender_map.get(attributes.get('gender'))}without a face in " + style + "dslr, ultra quality, dof, film grain, Fujifilm XT3, crystal clear, 8K UHD", "weight": 1.0},
            {"text": "poorly rendered", "weight": -1.0}
        ],
        "cfg_scale": 9,
        "seed": 4000,
        "steps": 50,
        "style_preset": "photographic",
    })
    modelId = "stability.stable-diffusion-xl"
    
    response = bedrock_runtime.invoke_model(body=request, modelId=modelId)
    response_body = json.loads(response.get("body").read())
    
    base_64_img_str = response_body["artifacts"][0].get("base64")
    # display.display(display.Image(b64decode(base_64_img_str), width=200))
    image_strip += "<td><img src='..."+ base_64_img_str + "'></td>"
    with open(f"data/aistylist/image_{i}.png", "wb") as fh:
            fh.write(base64.decodebytes(bytes(base_64_img_str, "utf-8")))

display.display(display.HTML("<table><tr>" + image_strip +"</tr></table>"))
# Out:
# <table><tr><td><img src='......'></td><td><img src='......'></td><td><img src='......'></td><td><img src='......'></td><td><img src='......'></td></tr></table>

# %% [markdown]
# ## Enhance user experience with Chatbot
#
# #### Generating detailed overview based on customer reviews of products in catalog
# We have discussed the key building blocks needed for the chatbot application and now we will start to create them. LangChain's [ConversationBufferMemory](https://python.langchain.com/docs/use_cases/question_answering/chat_vector_db) class provides an easy way to capture conversational memory for LLM chat applications. Claude will retrieve context through conversational memory using the prompt template. Note that this time our prompt template includes a {chat_history} variable where our chat history will be included to the prompt.
#
# The prompt template has both conversation memory as well as chat history as inputs along with the human input. Notice how the prompt also instructs Claude to not answer questions which it does not have the context for. This helps reduce hallucinations which is extremely important when creating end user facing applications which need to be factual.
#
#
# ![Architecture](./images/chatbot_products.png)

# %%
chat_prompt1 = "Show me specific reviews that talk about the quality of the fabric for the jacket."
chat_prompt2 = "What do people like about the business formal jacket?"

from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.chains.conversational_retrieval.prompts import CONDENSE_QUESTION_PROMPT

chat_history = []
memory_chain = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
conversation = ConversationalRetrievalChain.from_llm(
    llm=llm, 
    retriever=vectorstore_faiss.as_retriever(), 
    memory=memory_chain,
    condense_question_prompt=CONDENSE_QUESTION_PROMPT,
    get_chat_history=lambda h: h,
    chain_type='stuff', # 'refine',
    #max_tokens_limit=300
)

# Generate detailed reviews based on customer reviews of specific clothing in product catalog

try:
    chat_res1 = conversation.run({'question': chat_prompt1})
    print_ww(chat_res1)
except ValueError as error:
    if "AccessDeniedException" in str(error):
        class StopExecution(ValueError):
            def _render_traceback_(self):
                pass
        raise StopExecution
    else:
        raise error
# Out:
#  Based on the context provided, here are two reviews that specifically mention the quality of the
# fabric for the jackets:
#
# Coats, Jackets & Vests
# I was looking for a warm winter coat that would keep me comfortable during the cold months. I found
# exactly what I needed from this store's great selection of coats, jackets and vests. They have
# options for both men and women in various styles and fabrics like wool, down and fleece. The prices
# are very reasonable too. I'm happy with my purchase and would definitely shop here again for all my
# outerwear needs.
#
# Suiting & Blazers
# I was very impressed with the quality and fit of the suits and blazers from this company. The fabric
# was high-end and durable, with beautiful tailoring that gave a very polished look. The sales staff
# was knowledgable and helped me find the perfect suit for an upcoming event. I received many
# compliments and felt great wearing it. Overall, an outstanding shopping experience and I would
# highly recommend Suiting & Blazers for your formalwear needs.

# %%
try:
    chat_res2 = conversation.run({'question': chat_prompt2 + " Answer even if embeddings does not return anything."})
    print_ww(chat_res2)
except ValueError as error:
    if  "AccessDeniedException" in str(error):
        class StopExecution(ValueError):
            def _render_traceback_(self):
                pass
        raise StopExecution
    else:
        raise error
# Out:
#  Based on the context provided, the reviews indicate that people liked the following aspects of the
# business formal jackets:
#
# - High quality, durable fabric with beautiful tailoring that gave a polished, professional look.
#
# - The fit and silhouette were flattering.
#
# - The jackets paired well with other pieces to create versatile mix-and-match outfits for both
# office and weekend wear.
#
# - Carefully selected fabrics resisted wrinkles and provided lasting comfort.
#
# So in summary, the reviews suggest that customers appreciated the high-end materials, excellent
# construction, versatility, and comfort of the business formal jackets. The jackets seemed to meet
# people's needs for professional yet stylish attire.

# %% [markdown]
# #### Customer order history semantic searches
#
# Generating size and color recommendations based on customer's order history. This will help to provide curated content to the customer

# %%
chat_prompt3 = "What size and color should I wear?"
chat_res3 = wrapper_store_faiss.query(question= chat_prompt3 + " based on order history for customer with id " + customer_id, llm=llm)
print_ww(chat_res3)
# Out:
#  Based on the order history for customer with id 2, they have ordered the following items:
#
# Order 2 - Pant, size XS, color black
# Order 16 - Jeans, size M, color blue
# Order 11 - Pant, size M, color black
#
# So for this customer, I would recommend getting pants/jeans in size M and in the colors black or
# blue, since those seem to be their preferred sizes and colors based on previous orders.

# %% [markdown]
# ## Showing final products based on customer style selection
#
# Continuing on our architectural pattern we will change the prompt template and leverage the LLM to generate the `recommended` products based on the user selection and weather and other details. The key extraction entities will be
#
# 1. Leverage the customer initial prompt to generate the relevant ids
# 2. Extract the relevant products from the vector store
# 3. Physical ID for the products needed
#
#
#
# ![Architecture](./images/other_products.png)

# %%
from PIL import Image
import requests

prompt_template2 = """Human: Extract a list of products and their respective physical IDs from catalog that matches the style given below. 
The catalog of products is provided under <catalog></catalog> tags below.
<catalog>
{context}
</catalog>
Style: {question}

The output should be a JSON of the form <products>[{{"product": <description of the product from the catalog>, "physical_id":<physical id of the product from the catalog>}}, ...]</products>
Skip the preamble.
Assistant: """

PROMPT2 = PromptTemplate(
    template=prompt_template2, input_variables=["context", "question"]
)
qa2 = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore_faiss.as_retriever(
        search_type="similarity", search_kwargs={"k": 10}
    ),
    chain_type_kwargs={"prompt": PROMPT2},
    return_source_documents=True,
)

selected_style = styles[3]
print(selected_style)
cart_items = qa2({"query": selected_style })['result']
print_ww(cart_items)
# Out:
# A dark gray suit with a light pink dress shirt, navy and silver diagonal striped tie, black leather belt, and black cap-toe oxford shoes.
#  <products>
# [
#   {"product": "Shirts", "physical_id": "41W2pZSOQnL"},
#   {"product": "Suits & Sport Coats", "physical_id": "41kH1pver+L"},
#   {"product": "Pants", "physical_id": "41GLpqe8X8L"},
#   {"product": "Shoes", "physical_id": "51gyfZsuO1L"},
#   {"product": "Belts", "physical_id": "213hpl1G+1L"},
#   {"product": "Ties, Cummerbunds & Pocket Squares", "physical_id": "31bHZNe-i5L"}
# ]
# </products>

# %%
products = json.loads(re.findall('<products>(.*?)</products>', cart_items, re.DOTALL)[0])
products
# Out:
# [{'product': 'Shirts', 'physical_id': '41W2pZSOQnL'},
#  {'product': 'Suits & Sport Coats', 'physical_id': '41kH1pver+L'},
#  {'product': 'Pants', 'physical_id': '41GLpqe8X8L'},
#  {'product': 'Shoes', 'physical_id': '51gyfZsuO1L'},
#  {'product': 'Belts', 'physical_id': '213hpl1G+1L'},
#  {'product': 'Ties, Cummerbunds & Pocket Squares',
#   'physical_id': '31bHZNe-i5L'}]

# %%
from PIL import Image
from IPython import display
import requests
import urllib.parse

cart_item_strip = ""
for product in products:
    url = "https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/" + urllib.parse.quote(product['physical_id'].strip(), safe='', encoding=None, errors=None) + ".jpg"
    # im = Image.open(requests.get(url, stream=True).raw)
    cart_item_strip += "<td><img src='"+ url + "'></td>"
display.display(display.HTML("<table><tr>" + cart_item_strip +"</tr></table>"))
# Out:
# <table><tr><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/41W2pZSOQnL.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/41kH1pver%2BL.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/41GLpqe8X8L.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/51gyfZsuO1L.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/213hpl1G%2B1L.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/31bHZNe-i5L.jpg'></td></tr></table>

# %% [markdown]
# ## Integrating DIY Agents to associate external APIs and databases
# ### Using ReAct: Synergizing Reasoning and Acting in Language Models Framework
# Large language models can generate both explanations for their reasoning and task-specific responses in an alternating fashion.
#
# Producing reasoning explanations enables the model to infer, monitor, and revise action plans, and even handle unexpected scenarios. The action step allows the model to interface with and obtain information from external sources such as knowledge bases or environments.
#
# The ReAct framework could enable large language models to interact with external tools to obtain additional information that results in more accurate and fact-based responses. Here we will leverage the user prompt and perform the following actions
# 1. Extract the city
# 2. Get weather information
# 3. Search our product catalog using semantic search to find relevant products
# 4. Display the products for user to add to cart
#
# ![Architecture](./images/weather.png)

# %%
import os
import python_weather

async def getweather(city):
  # declare the client. the measuring unit used defaults to the metric system (celcius, km/h, etc.)
  async with python_weather.Client(unit=python_weather.IMPERIAL) as client:
    # fetch a weather forecast from a city
    weather = await client.get(city)
    
    # returns the current day's forecast temperature (int)
    return weather.current

# %% [markdown]
# ## Accessory recommendations
#
# We will provide  accessory recommendations based on location provided in customer input

# %%
await getweather(entity_extraction_result[2])
# Out:
# <CurrentForecast temperature=50 description='Light rain shower' kind="Kind.LIGHT_RAIN">

# %%
import asyncio
accessory_response = None
if attributes["location"]:
    current_weather = await getweather(entity_extraction_result[2])
    accessory_input = "Suggest list of accessories based on the weather and the selected style. It is " + current_weather.description + " with temperature at " + str(current_weather.temperature) +" degrees fahrenheit.\n Selected Style: " + styles[0]
    accessory_response = qa({"query": accessory_input})['result']
    print_ww(accessory_response)
# Out:
#  <style>Trench coat</style>
# <style>Umbrella</style>
# <style>Leather gloves</style>
# <style>Wool scarf</style>
# <style>Waterproof boots</style>

# %%
if accessory_response:
    accessories = re.findall('<style>(.*?)</style>', accessory_response.strip(), re.DOTALL)
    accessories_items = qa2({"query": ', '.join(accessories)})['result']
    accessories_items = json.loads(re.findall('<products>(.*?)</products>', accessories_items, re.DOTALL)[0])
    accessory_strip = ""
    for accessory in accessories_items:
        url = "https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/" + urllib.parse.quote(accessory['physical_id'].strip(), safe='', encoding=None, errors=None) + ".jpg"
        accessory_strip += "<td><img src='"+ url + "'></td>"
    display.display(display.HTML("<table><tr>" + accessory_strip +"</tr></table>"))
# Out:
# <table><tr><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/41pFFEkD-ML.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/31u6In5mHyL.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/41Hv0zWAvIL.jpg'></td><td><img src='https://sagemaker-example-files-prod-us-east-1.s3.us-east-1.amazonaws.com/datasets/image/howser-bedrock/data/aistylist/images/products/31O0n5kWVxL.jpg'></td></tr></table>

# %% [markdown]
# ## Simulate the order check out
#
# Add a customer data table to complete the order transaction. This information provides the shipping address for the outfit order.

# %%
customer_table=[{"id": 1, "first_name": "John", "last_name": "Doe", "age": 35, "address": "123 Bedrock st, California 90210"},
  {"id": 2, "first_name": "Jane", "last_name": "Smith", "age": 27, "address": "234 Sagemaker drive, Texas 12345"},
  {"id": 3, "first_name": "Bob", "last_name": "Jones", "age": 42, "address": "111 DeepRacer ct, Virginia 55555"},
  {"id": 4, "first_name": "Sara", "last_name": "Miller", "age": 29, "address": "222 Robomaker ave, New Yotk 13579"},
  {"id": 5, "first_name": "Mark", "last_name": "Davis", "age": 31, "address": "444 Transcribe blvd, Florida 02468"},
  {"id": 6, "first_name": "Laura", "last_name": "Wilson", "age": 24, "address": "555 CodeGuru st, California 98765" },
  {"id": 7, "first_name": "Steve", "last_name": "Moore", "age": 36, "address": "456 DeepLens st, Texas 11223"},
  {"id": 8, "first_name": "Michelle", "last_name": "Chen", "age": 22, "address": "642 DeepCompose st, Colorado 33215"},
  {"id": 9, "first_name": "David", "last_name": "Lee", "age": 29, "address": "777 S3 st, California 99567"},
  {"id": 10, "first_name": "Jessica", "last_name": "Brown", "age": 18, "address": "909 Ec st, Utah 43210"}]

def address_lookup(id):
    for customer in customer_table:
        if customer["id"] == int(id):
            return customer
        
    return None

print(address_lookup(customer_id)["address"])
# Out:
# 234 Sagemaker drive, Texas 12345
